# %% [markdown]
# ## Load and Prepare Data

# %% [markdown]
# ### Import needed modules

# %%
import arcgis
import pandas as pd
import os
import arcpy

# %% [markdown]
# ### Read data into python

# %%
table_csv_path="countypres2016.csv"

# %%
data_df=pd.read_csv(table_csv_path,dtype={'FIPS':str})
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
data_df.head()
# Out:
#    year    state state_po   county  FIPS     office        candidate  \
# 0  2016  Alabama       AL  Autauga  1001  President  Hillary Clinton
# 1  2016  Alabama       AL  Autauga  1001  President     Donald Trump
# 2  2016  Alabama       AL  Autauga  1001  President            Other
# 3  2016  Alabama       AL  Baldwin  1003  President  Hillary Clinton
# 4  2016  Alabama       AL  Baldwin  1003  President     Donald Trump
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          5936.0       24973  20190722
# 1  republican         18172.0       24973  20190722
# 2         NaN           865.0       24973  20190722
# 3    democrat         18458.0       95215  20190722
# 4  republican         72883.0       95215  20190722

# %% [markdown]
# ### Handle Missing data
#
# The election data includes a records that are missing data in the FIPS field. This missing data is referred to as null values. You will identify how many rows have null values and create a new dataframe that does not include them.

# %%
data_df.loc[data_df['FIPS'].isnull()]
# Out:
#       year         state state_po             county FIPS     office  \
# 9462  2016   Connecticut      NaN  Statewide writein  NaN  President
# 9463  2016         Maine      NaN       Maine UOCAVA  NaN  President
# 9464  2016        Alaska      NaN        District 99  NaN  President
# 9465  2016  Rhode Island      NaN   Federal Precinct  NaN  President
# 9466  2016   Connecticut      NaN  Statewide writein  NaN  President
# 9467  2016         Maine      NaN       Maine UOCAVA  NaN  President
# 9468  2016        Alaska      NaN        District 99  NaN  President
# 9469  2016  Rhode Island      NaN   Federal Precinct  NaN  President
# 9470  2016   Connecticut      NaN  Statewide writein  NaN  President
# 9471  2016         Maine      NaN       Maine UOCAVA  NaN  President
# 9472  2016        Alaska      NaN        District 99  NaN  President
# 9473  2016  Rhode Island      NaN   Federal Precinct  NaN  President
#
#             candidate       party  candidatevotes  totalvotes   version
# 9462  Hillary Clinton    democrat             NaN        5056  20190722
# 9463  Hillary Clinton    democrat          3017.0        5056  20190722
# 9464  Hillary Clinton    democrat           274.0        5056  20190722
# 9465  Hillary Clinton    democrat           637.0        5056  20190722
# 9466     Donald Trump  republican             NaN        5056  20190722
# 9467     Donald Trump  republican           648.0        5056  20190722
# 9468     Donald Trump  republican            40.0        5056  20190722
# 9469     Donald Trump  republican            53.0        5056  20190722
# 9470            Other         NaN             NaN        5056  20190722
# 9471            Other         NaN           321.0        5056  20190722
# 9472            Other         NaN            28.0        5056  20190722
# 9473            Other         NaN            38.0        5056  20190722

# %%
# get rows count
rowcount=data_df.shape[0]
# get rows count for FIPS = null
null_fips_rowcount= data_df.loc[data_df['FIPS'].isnull()].shape[0]
# Calculate how much of the data this represents as a percentage
null_fips_rowcount_percent=round((null_fips_rowcount/rowcount)*100,2)
# Use a print statement to report this information
print("There were "+str(null_fips_rowcount)+" records with null FIPS values in the data.\nThis amounts to " +str(null_fips_rowcount_percent)+"% of the available data.")
# Out:
# There were 12 records with null FIPS values in the data.
# This amounts to 0.13% of the available data.

# %%
# Use the notnull function and the loc function to create a new dataframe without null FIPS records
data_df=data_df.loc[data_df['FIPS'].notnull()]
# Out:
#       year    state state_po    county   FIPS     office        candidate  \
# 0     2016  Alabama       AL   Autauga   1001  President  Hillary Clinton
# 1     2016  Alabama       AL   Autauga   1001  President     Donald Trump
# 2     2016  Alabama       AL   Autauga   1001  President            Other
# 3     2016  Alabama       AL   Baldwin   1003  President  Hillary Clinton
# 4     2016  Alabama       AL   Baldwin   1003  President     Donald Trump
# ...    ...      ...      ...       ...    ...        ...              ...
# 9457  2016  Wyoming       WY  Washakie  56043  President     Donald Trump
# 9458  2016  Wyoming       WY  Washakie  56043  President            Other
# 9459  2016  Wyoming       WY    Weston  56045  President  Hillary Clinton
# 9460  2016  Wyoming       WY    Weston  56045  President     Donald Trump
# 9461  2016  Wyoming       WY    Weston  56045  President            Other
#
#            party  candidatevotes  totalvotes   version
# 0       democrat          5936.0       24973  20190722
# 1     republican         18172.0       24973  20190722
# 2            NaN           865.0       24973  20190722
# 3       democrat         18458.0       95215  20190722
# 4     republican         72883.0       95215  20190722
# ...          ...             ...         ...       ...
# 9457  republican          2911.0        3814  20190722
# 9458         NaN           371.0        3814  20190722
# 9459    democrat           299.0        3526  20190722
# 9460  republican          3033.0        3526  20190722
# 9461         NaN           194.0        3526  20190722
#
# [9462 rows x 11 columns]

# %% [markdown]
# In reviewing your data, you notice that the FIPS field is considered a numeric field instead of a string. As a result, leading zeroes in the FIPS values have been removed. The resulting FIPS values only have four characters instead of five. You will determine how many records are missing leading zeroes and add, or append, the missing zero.

# %%
trunc_df=data_df.loc[data_df['FIPS'].str.len()==4]
trunc_df_percent=round((trunc_df.shape[0]/data_df.shape[0])*100,2)
# Use another print statement (using the f format key) to report this information
print(f"{trunc_df_percent}% of data ({trunc_df.shape[0]} rows) has truncated FIPS values.")
# Out:
# 10.37% of data (981 rows) has truncated FIPS values.

# %% [markdown]
# The following cell creates a function in python that adds a leading zero to the FIPS value if it only has four characters.

# %%
# Define a helper function to fix truncated zeros, with one parameter: the value to be processed
def fix_trunc_zeros(val):
    # Use an if statement to check if there are four characters in the string representation of the value
    if len(str(val)) == 4:
        # If this is the case, return the value with an appended "0" in the front
        return "0"+str(val)
    # Otherwise...
    else:
        # Return the value itself
        return str(val)

# %%
# Test helper function with truncated value
fix_trunc_zeros(7042)  # You should see an appended zero: "07042"
# Out:
# '07042'

# %%
# Run helper function on the FIPS field using the apply and lambda method 
data_df['FIPS'] = data_df['FIPS'].apply(lambda x: fix_trunc_zeros(x))
# Print information on the operation performed, and show the first few records to confirm it worked
print(f"{trunc_df_percent}% of data ({trunc_df.shape[0]} rows) had truncated FIPS IDs corrected.")
data_df.head()
# Out:
# 10.37% of data (981 rows) had truncated FIPS IDs corrected.
#    year    state state_po   county   FIPS     office        candidate  \
# 0  2016  Alabama       AL  Autauga  01001  President  Hillary Clinton
# 1  2016  Alabama       AL  Autauga  01001  President     Donald Trump
# 2  2016  Alabama       AL  Autauga  01001  President            Other
# 3  2016  Alabama       AL  Baldwin  01003  President  Hillary Clinton
# 4  2016  Alabama       AL  Baldwin  01003  President     Donald Trump
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          5936.0       24973  20190722
# 1  republican         18172.0       24973  20190722
# 2         NaN           865.0       24973  20190722
# 3    democrat         18458.0       95215  20190722
# 4  republican         72883.0       95215  20190722

# %%
# Set an index using mulitple fields, which "locks" these fields before the table pivots
# Use the built-in groupby function for the FIPS and year fields, which you use to group the data by candidate
# Use unstack to perform the table pivot, which will rotate the table and turn rows into columns
df_out = data_df.set_index(['FIPS', 
                            'year', 
                            'county', 
                            'state', 
                            'state_po', 
                            'office', 
                            data_df.groupby(['FIPS', 'year']).cumcount()+1]).unstack()

# Use the indexes for the columns to set column names (Ex: candidate_1, candidate_2, votes_1, votes_2, etc.)
df_out.columns = df_out.columns.map('{0[0]}_{0[1]}'.format)

# Rename columns 
df_out = df_out.rename(columns={"candidate_1": "candidate_dem",
                                "candidatevotes_1": "votes_dem",
                                "candidate_2": "candidate_gop",
                                "candidatevotes_2": "votes_gop",
                                "totalvotes_1": "votes_total",
                                "state_po": "state_abbrev"
                                })

# Keep only the necessary columns
df_out = df_out[["candidate_dem", "votes_dem",
                 "candidate_gop", "votes_gop",
                 "votes_total"]]

# Remove the multiindex since we no longer need these fields to be "locked" for the pivot
df_out.reset_index(inplace=True)

# Print out the first few records to confirm everything worked
df_out.head()
# Out:
#     FIPS  year   county    state state_po     office    candidate_dem  \
# 0  01001  2016  Autauga  Alabama       AL  President  Hillary Clinton
# 1  01003  2016  Baldwin  Alabama       AL  President  Hillary Clinton
# 2  01005  2016  Barbour  Alabama       AL  President  Hillary Clinton
# 3  01007  2016     Bibb  Alabama       AL  President  Hillary Clinton
# 4  01009  2016   Blount  Alabama       AL  President  Hillary Clinton
#
#    votes_dem candidate_gop  votes_gop  votes_total
# 0     5936.0  Donald Trump    18172.0        24973
# 1    18458.0  Donald Trump    72883.0        95215
# 2     4871.0  Donald Trump     5454.0        10469
# 3     1874.0  Donald Trump     6738.0         8819
# 4     2156.0  Donald Trump    22859.0        25588

# %% [markdown]
# ##### Calculate an attribute for the total votes for non major party

# %%
# Calculate votes that did not choose the Democratic or Republican party
df_out['votes_other'] = df_out['votes_total'] - (df_out['votes_dem'] + df_out['votes_gop'])
df_out.head()
# Out:
#     FIPS  year   county    state state_po     office    candidate_dem  \
# 0  01001  2016  Autauga  Alabama       AL  President  Hillary Clinton
# 1  01003  2016  Baldwin  Alabama       AL  President  Hillary Clinton
# 2  01005  2016  Barbour  Alabama       AL  President  Hillary Clinton
# 3  01007  2016     Bibb  Alabama       AL  President  Hillary Clinton
# 4  01009  2016   Blount  Alabama       AL  President  Hillary Clinton
#
#    votes_dem candidate_gop  votes_gop  votes_total  votes_other
# 0     5936.0  Donald Trump    18172.0        24973        865.0
# 1    18458.0  Donald Trump    72883.0        95215       3874.0
# 2     4871.0  Donald Trump     5454.0        10469        144.0
# 3     1874.0  Donald Trump     6738.0         8819        207.0
# 4     2156.0  Donald Trump    22859.0        25588        573.0

# %% [markdown]
# ##### Calculate additional attributes

# %%
# Calculate voter share attributes
df_out['voter_share_major_party'] = (df_out['votes_dem'] + df_out['votes_gop']) / df_out['votes_total']
df_out['voter_share_dem'] = df_out['votes_dem'] / df_out['votes_total']
df_out['voter_share_gop'] = df_out['votes_gop'] / df_out['votes_total']
df_out['voter_share_other'] = df_out['votes_other'] / df_out['votes_total']

# Calculate raw difference attributes
df_out['rawdiff_dem_vs_gop'] = df_out['votes_dem'] - df_out['votes_gop']
df_out['rawdiff_gop_vs_dem'] = df_out['votes_gop'] - df_out['votes_dem']
df_out['rawdiff_dem_vs_other'] = df_out['votes_dem'] - df_out['votes_other']
df_out['rawdiff_gop_vs_other'] = df_out['votes_gop'] - df_out['votes_other']
df_out['rawdiff_other_vs_dem'] = df_out['votes_other'] - df_out['votes_dem']
df_out['rawdiff_other_vs_gop'] = df_out['votes_other'] - df_out['votes_gop']

# Calculate percent difference attributes
df_out['pctdiff_dem_vs_gop'] = (df_out['votes_dem'] - df_out['votes_gop']) / df_out['votes_total']
df_out['pctdiff_gop_vs_dem'] = (df_out['votes_gop'] - df_out['votes_dem']) / df_out['votes_total']
df_out['pctdiff_dem_vs_other'] = (df_out['votes_dem'] - df_out['votes_other']) / df_out['votes_total']
df_out['pctdiff_gop_vs_other'] = (df_out['votes_gop'] - df_out['votes_other']) / df_out['votes_total']
df_out['pctdiff_other_vs_dem'] = (df_out['votes_other'] - df_out['votes_dem']) / df_out['votes_total']
df_out['pctdiff_other_vs_gop'] = (df_out['votes_other'] - df_out['votes_gop']) / df_out['votes_total']

df_out.head()
# Out:
#     FIPS  year   county    state state_po     office    candidate_dem  \
# 0  01001  2016  Autauga  Alabama       AL  President  Hillary Clinton
# 1  01003  2016  Baldwin  Alabama       AL  President  Hillary Clinton
# 2  01005  2016  Barbour  Alabama       AL  President  Hillary Clinton
# 3  01007  2016     Bibb  Alabama       AL  President  Hillary Clinton
# 4  01009  2016   Blount  Alabama       AL  President  Hillary Clinton
#
#    votes_dem candidate_gop  votes_gop  votes_total  votes_other  \
# 0     5936.0  Donald Trump    18172.0        24973        865.0
# 1    18458.0  Donald Trump    72883.0        95215       3874.0
# 2     4871.0  Donald Trump     5454.0        10469        144.0
# 3     1874.0  Donald Trump     6738.0         8819        207.0
# 4     2156.0  Donald Trump    22859.0        25588        573.0
#
#    voter_share_major_party  voter_share_dem  voter_share_gop  \
# 0                 0.965363         0.237697         0.727666
# 1                 0.959313         0.193856         0.765457
# 2                 0.986245         0.465278         0.520967
# 3                 0.976528         0.212496         0.764032
# 4                 0.977607         0.084258         0.893348
#
#    voter_share_other  rawdiff_dem_vs_gop  rawdiff_gop_vs_dem  \
# 0           0.034637            -12236.0             12236.0
# 1           0.040687            -54425.0             54425.0
# 2           0.013755              -583.0               583.0
# 3           0.023472             -4864.0              4864.0
# 4           0.022393            -20703.0             20703.0
#
#    rawdiff_dem_vs_other  rawdiff_gop_vs_other  rawdiff_other_vs_dem  \
# 0                5071.0               17307.0               -5071.0
# 1               14584.0               69009.0              -14584.0
# 2                4727.0                5310.0               -4727.0
# 3                1667.0                6531.0               -1667.0
# 4                1583.0               22286.0               -1583.0
#
#    rawdiff_other_vs_gop  pctdiff_dem_vs_gop  pctdiff_gop_vs_dem  \
# 0              -17307.0           -0.489969            0.489969
# 1              -69009.0           -0.571601            0.571601
# 2               -5310.0           -0.055688            0.055688
# 3               -6531.0           -0.551536            0.551536
# 4              -22286.0           -0.809090            0.809090
#
#    pctdiff_dem_vs_other  pctdiff_gop_vs_other  pctdiff_other_vs_dem  \
# 0              0.203059              0.693028             -0.203059
# 1              0.153169              0.724770             -0.153169
# 2              0.451524              0.507212             -0.451524
# 3              0.189024              0.740560             -0.189024
# 4              0.061865              0.870955             -0.061865
#
#    pctdiff_other_vs_gop
# 0             -0.693028
# 1             -0.724770
# 2             -0.507212
# 3             -0.740560
# 4             -0.870955

# %% [markdown]
# ### Geoenable the data
#
# You will eventually use this data in a spatial analysis. This means that the data needs to include location information to determine where the data is located on a map. You will geoenable the data, or add location to the data, using existing geoenabled county data.
#
# Define the ArcGIS Pro project, database, and existing geoenabled data

# %%
arcpy.mp
# Out:
# <module 'arcpy.mp' from 'c:\\program files\\arcgis\\pro\\Resources\\arcpy\\arcpy\\mp.py'>

# %%
# Create variables that represent the ArcGIS Pro project and map
aprx = arcpy.mp.ArcGISProject("CURRENT")
mp = aprx.listMaps('Data Engineering')[0]

# Create a variable that represents the default file geodatabase
fgdb = r"Data Engineering and Visualization.gdb"
aprx.defaultGeodatabase = fgdb
arcpy.env.workspace = fgdb

# %%
# Create a variable that represents the county geometry dataset
counties_fc_name = "Counties_2016_VotingAgePopulation"
counties_fc = os.path.join(fgdb, counties_fc_name)

# %%
counties_fc
# Out:
# 'Data Engineering and Visualization.gdb\\Counties_2016_VotingAgePopulation'

# %%
# Load the dataset into a spatially-enabled dataframe
counties_df = pd.DataFrame.spatial.from_featureclass(counties_fc)
counties_df.head()
# Out:
#    OBJECTID  COUNTYNS  GEOID        NAMELSAD                  GEONAME  \
# 0         1  00161526  01001  Autauga County  Autauga County, Alabama
# 1         2  00161527  01003  Baldwin County  Baldwin County, Alabama
# 2         3  00161528  01005  Barbour County  Barbour County, Alabama
# 3         4  00161529  01007     Bibb County     Bibb County, Alabama
# 4         5  00161530  01009   Blount County   Blount County, Alabama
#
#         GEOID_1  LNNUMBER  Total_tot_est  Total_adu_est  Total_cit_est  \
# 0  05000US01001        13          55050          41195          54510
# 1  05000US01003        13         199510         155240         195655
# 2  05000US01005        13          26615          20880          26085
# 3  05000US01007        13          22570          17815          22345
# 4  05000US01009        13          57705          44105          55925
#
#    Total_cvap_est  nHispLat_tot_est  nHispLat_adu_est  nHispLat_cit_est  \
# 0           40690             53635             40290             53325
# 1          151770            190800            149730            188875
# 2           20375             25465             20180             25405
# 3           17590             22070             17440             22050
# 4           42430             52670             41085             52450
#
#    nHispLat_cvap_est  AIAN_tot_est  AIAN_adu_est  AIAN_cit_est  AIAN_cvap_est  \
# 0              40015           225           125           225            125
# 1             148020          1230          1125          1200           1095
# 2              20120            45            45            45             45
# 3              17415            80            45            80             45
# 4              40885           170           155           170            155
#
#    Asian_tot_est  Asian_adu_est  Asian_cit_est  Asian_cvap_est  BAA_tot_est  \
# 0            485            390            340             245        10115
# 1           1785           1195           1065             615        18500
# 2            120             45            110              40        12765
# 3             15             15              0               0         4790
# 4             90             80             75              65          905
#
#    BAA_adu_est  BAA_cit_est  BAA_cvap_est  NHOPI_tot_est  NHOPI_adu_est  \
# 0         7470        10115          7470              4              4
# 1        13570        18245         13315              0              0
# 2         9650        12745          9635              0              0
# 3         3875         4790          3875              0              0
# 4          675          895           675              0              0
#
#    NHOPI_cit_est  NHOPI_cvap_est  White_tot_est  White_adu_est  White_cit_est  \
# 0              4               4          41795          31835          41635
# 1              0               0         166275         132280         165455
# 2              0               0          12390          10340          12360
# 3              0               0          16875          13255          16870
# 4              0               0          50710          39710          50580
#
#    White_cvap_est  AIAN_W_tot_est  AIAN_W_adu_est  AIAN_W_cit_est  \
# 0           31705             230             220             230
# 1          131535            1275             795            1275
# 2           10310              65              65              65
# 3           13250              65              65              65
# 4           39580             450             360             450
#
#    AIAN_W_cvap_est  Asian_W_tot_est  Asian_W_adu_est  Asian_W_cit_est  \
# 0              220              270              140              270
# 1              795              590              395              500
# 2               65               25                0               25
# 3               65                0                0                0
# 4              360              105               75               55
#
#    Asian_W_cvap_est  BAA_W_tot_est  BAA_W_adu_est  BAA_W_cit_est  \
# 0               140            420             50            420
# 1               305           1035            260           1035
# 2                 0             45             20             45
# 3                 0            230            170            230
# 4                25            175             25            175
#
#    BAA_W_cvap_est  AIAN_BAA_tot_est  AIAN_BAA_adu_est  AIAN_BAA_cit_est  \
# 0              50                 0                 0                 0
# 1             260                55                55                55
# 2              15                 4                 4                 4
# 3             170                 0                 0                 0
# 4              25                 0                 0                 0
#
#    AIAN_BAA_cvap_est  Rem_TOM_tot_est  Rem_TOM_adu_est  Rem_TOM_cit_est  \
# 0                  0               90               55               90
# 1                 55               50               50               45
# 2                  4                4                4                4
# 3                  0               15               15               15
# 4                  0               60                4               45
#
#    Rem_TOM_cvap_est  HispLat_tot_est  HispLat_adu_est  HispLat_cit_est  \
# 0                55             1415              905             1185
# 1                45             8710             5510             6780
# 2                 4             1145              700              680
# 3                15              500              380              295
# 4                 4             5035             3015             3475
#
#    HispLat_cvap_est   Shape__Area  Shape__Length  \
# 0               675  2.208654e+09   2.498864e+05
# 1              3750  5.671048e+09   1.655940e+06
# 2               250  3.257902e+09   3.208964e+05
# 3               175  2.311999e+09   2.279184e+05
# 4              1550  2.456909e+09   2.926429e+05
#
#                                                SHAPE
# 0  {'rings': [[[-9619465, 3856529.0001000017], [-...
# 1  {'rings': [[[-9746859, 3539643.0001000017], [-...
# 2  {'rings': [[[-9468394, 3771591.0001000017], [-...
# 3  {'rings': [[[-9692114, 3928124.0001000017], [-...
# 4  {'rings': [[[-9623907, 4063676.0001000017], [-...

# %%
# Modify the dataframe to only include the attributes that are needed
counties_df = counties_df[['OBJECTID', 'GEOID', 'GEONAME',
                           'Total_cvap_est',
                           'SHAPE', 'Shape__Area', 'Shape__Length']]
counties_df.head()
# Out:
#    OBJECTID  GEOID                  GEONAME  Total_cvap_est  \
# 0         1  01001  Autauga County, Alabama           40690
# 1         2  01003  Baldwin County, Alabama          151770
# 2         3  01005  Barbour County, Alabama           20375
# 3         4  01007     Bibb County, Alabama           17590
# 4         5  01009   Blount County, Alabama           42430
#
#                                                SHAPE   Shape__Area  \
# 0  {'rings': [[[-9619465, 3856529.0001000017], [-...  2.208654e+09
# 1  {'rings': [[[-9746859, 3539643.0001000017], [-...  5.671048e+09
# 2  {'rings': [[[-9468394, 3771591.0001000017], [-...  3.257902e+09
# 3  {'rings': [[[-9692114, 3928124.0001000017], [-...  2.311999e+09
# 4  {'rings': [[[-9623907, 4063676.0001000017], [-...  2.456909e+09
#
#    Shape__Length
# 0   2.498864e+05
# 1   1.655940e+06
# 2   3.208964e+05
# 3   2.279184e+05
# 4   2.926429e+05

# %%
# Join the election dataframe with the county geometry dataframe
geo_df = pd.merge(df_out, counties_df, left_on='FIPS', right_on="GEOID", how='left')

# Visualize the merged data
geo_df.head()
geo_df.tail()
# Out:
#        FIPS  year      county    state state_po     office    candidate_dem  \
# 3149  56037  2016  Sweetwater  Wyoming       WY  President  Hillary Clinton
# 3150  56039  2016       Teton  Wyoming       WY  President  Hillary Clinton
# 3151  56041  2016       Uinta  Wyoming       WY  President  Hillary Clinton
# 3152  56043  2016    Washakie  Wyoming       WY  President  Hillary Clinton
# 3153  56045  2016      Weston  Wyoming       WY  President  Hillary Clinton
#
#       votes_dem candidate_gop  votes_gop  votes_total  votes_other  \
# 3149     3231.0  Donald Trump    12154.0        17130       1745.0
# 3150     7314.0  Donald Trump     3921.0        12627       1392.0
# 3151     1202.0  Donald Trump     6154.0         8470       1114.0
# 3152      532.0  Donald Trump     2911.0         3814        371.0
# 3153      299.0  Donald Trump     3033.0         3526        194.0
#
#       voter_share_major_party  voter_share_dem  voter_share_gop  \
# 3149                 0.898132         0.188616         0.709515
# 3150                 0.889760         0.579235         0.310525
# 3151                 0.868477         0.141913         0.726564
# 3152                 0.902727         0.139486         0.763241
# 3153                 0.944980         0.084799         0.860182
#
#       voter_share_other  rawdiff_dem_vs_gop  rawdiff_gop_vs_dem  \
# 3149           0.101868             -8923.0              8923.0
# 3150           0.110240              3393.0             -3393.0
# 3151           0.131523             -4952.0              4952.0
# 3152           0.097273             -2379.0              2379.0
# 3153           0.055020             -2734.0              2734.0
#
#       rawdiff_dem_vs_other  rawdiff_gop_vs_other  rawdiff_other_vs_dem  \
# 3149                1486.0               10409.0               -1486.0
# 3150                5922.0                2529.0               -5922.0
# 3151                  88.0                5040.0                 -88.0
# 3152                 161.0                2540.0                -161.0
# 3153                 105.0                2839.0                -105.0
#
#       rawdiff_other_vs_gop  pctdiff_dem_vs_gop  pctdiff_gop_vs_dem  \
# 3149              -10409.0           -0.520899            0.520899
# 3150               -2529.0            0.268710           -0.268710
# 3151               -5040.0           -0.584652            0.584652
# 3152               -2540.0           -0.623755            0.623755
# 3153               -2839.0           -0.775383            0.775383
#
#       pctdiff_dem_vs_other  pctdiff_gop_vs_other  pctdiff_other_vs_dem  \
# 3149              0.086748              0.607647             -0.086748
# 3150              0.468995              0.200285             -0.468995
# 3151              0.010390              0.595041             -0.010390
# 3152              0.042213              0.665967             -0.042213
# 3153              0.029779              0.805162             -0.029779
#
#       pctdiff_other_vs_gop  OBJECTID  GEOID                     GEONAME  \
# 3149             -0.607647    3138.0  56037  Sweetwater County, Wyoming
# 3150             -0.200285    3139.0  56039       Teton County, Wyoming
# 3151             -0.595041    3140.0  56041       Uinta County, Wyoming
# 3152             -0.665967    3141.0  56043    Washakie County, Wyoming
# 3153             -0.805162    3142.0  56045      Weston County, Wyoming
#
#       Total_cvap_est                                              SHAPE  \
# 3149         30565.0  {'rings': [[[-12138709, 5200561.000100002], [-...
# 3150         16335.0  {'rings': [[[-12251065, 5466685.000100002], [-...
# 3151         14355.0  {'rings': [[[-12250489, 5097977.000100002], [-...
# 3152          6135.0  {'rings': [[[-11927529, 5491116.000100002], [-...
# 3153          5565.0  {'rings': [[[-11583294, 5493400.000100002], [-...
#
#        Shape__Area  Shape__Length
# 3149  4.872260e+10  948272.972406
# 3150  2.106504e+10  693521.176635
# 3151  9.587254e+09  394527.582056
# 3152  1.119276e+10  530268.026733
# 3153  1.195222e+10  437743.701854

# %%
# Create a copy of the data, and perform a query
data_2016_df = geo_df.copy()
data_2016_df.query("year == '2016'", inplace=True)
data_2016_df.head()
# Out:
#     FIPS  year   county    state state_po     office    candidate_dem  \
# 0  01001  2016  Autauga  Alabama       AL  President  Hillary Clinton
# 1  01003  2016  Baldwin  Alabama       AL  President  Hillary Clinton
# 2  01005  2016  Barbour  Alabama       AL  President  Hillary Clinton
# 3  01007  2016     Bibb  Alabama       AL  President  Hillary Clinton
# 4  01009  2016   Blount  Alabama       AL  President  Hillary Clinton
#
#    votes_dem candidate_gop  votes_gop  votes_total  votes_other  \
# 0     5936.0  Donald Trump    18172.0        24973        865.0
# 1    18458.0  Donald Trump    72883.0        95215       3874.0
# 2     4871.0  Donald Trump     5454.0        10469        144.0
# 3     1874.0  Donald Trump     6738.0         8819        207.0
# 4     2156.0  Donald Trump    22859.0        25588        573.0
#
#    voter_share_major_party  voter_share_dem  voter_share_gop  \
# 0                 0.965363         0.237697         0.727666
# 1                 0.959313         0.193856         0.765457
# 2                 0.986245         0.465278         0.520967
# 3                 0.976528         0.212496         0.764032
# 4                 0.977607         0.084258         0.893348
#
#    voter_share_other  rawdiff_dem_vs_gop  rawdiff_gop_vs_dem  \
# 0           0.034637            -12236.0             12236.0
# 1           0.040687            -54425.0             54425.0
# 2           0.013755              -583.0               583.0
# 3           0.023472             -4864.0              4864.0
# 4           0.022393            -20703.0             20703.0
#
#    rawdiff_dem_vs_other  rawdiff_gop_vs_other  rawdiff_other_vs_dem  \
# 0                5071.0               17307.0               -5071.0
# 1               14584.0               69009.0              -14584.0
# 2                4727.0                5310.0               -4727.0
# 3                1667.0                6531.0               -1667.0
# 4                1583.0               22286.0               -1583.0
#
#    rawdiff_other_vs_gop  pctdiff_dem_vs_gop  pctdiff_gop_vs_dem  \
# 0              -17307.0           -0.489969            0.489969
# 1              -69009.0           -0.571601            0.571601
# 2               -5310.0           -0.055688            0.055688
# 3               -6531.0           -0.551536            0.551536
# 4              -22286.0           -0.809090            0.809090
#
#    pctdiff_dem_vs_other  pctdiff_gop_vs_other  pctdiff_other_vs_dem  \
# 0              0.203059              0.693028             -0.203059
# 1              0.153169              0.724770             -0.153169
# 2              0.451524              0.507212             -0.451524
# 3              0.189024              0.740560             -0.189024
# 4              0.061865              0.870955             -0.061865
#
#    pctdiff_other_vs_gop  OBJECTID  GEOID                  GEONAME  \
# 0             -0.693028       1.0  01001  Autauga County, Alabama
# 1             -0.724770       2.0  01003  Baldwin County, Alabama
# 2             -0.507212       3.0  01005  Barbour County, Alabama
# 3             -0.740560       4.0  01007     Bibb County, Alabama
# 4             -0.870955       5.0  01009   Blount County, Alabama
#
#    Total_cvap_est                                              SHAPE  \
# 0         40690.0  {'rings': [[[-9619465, 3856529.0001000017], [-...
# 1        151770.0  {'rings': [[[-9746859, 3539643.0001000017], [-...
# 2         20375.0  {'rings': [[[-9468394, 3771591.0001000017], [-...
# 3         17590.0  {'rings': [[[-9692114, 3928124.0001000017], [-...
# 4         42430.0  {'rings': [[[-9623907, 4063676.0001000017], [-...
#
#     Shape__Area  Shape__Length
# 0  2.208654e+09   2.498864e+05
# 1  5.671048e+09   1.655940e+06
# 2  3.257902e+09   3.208964e+05
# 3  2.311999e+09   2.279184e+05
# 4  2.456909e+09   2.926429e+05

# %%
# Calculate voter turnout attributes
data_2016_df['voter_turnout'] = data_2016_df['votes_total'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_majparty'] = (data_2016_df['votes_dem']+data_2016_df['votes_gop']) / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_dem'] = data_2016_df['votes_dem'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_gop'] = data_2016_df['votes_gop'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_other'] = data_2016_df['votes_other'] / data_2016_df['Total_cvap_est']
data_2016_df.head()
# Out:
#     FIPS  year   county    state state_po     office    candidate_dem  \
# 0  01001  2016  Autauga  Alabama       AL  President  Hillary Clinton
# 1  01003  2016  Baldwin  Alabama       AL  President  Hillary Clinton
# 2  01005  2016  Barbour  Alabama       AL  President  Hillary Clinton
# 3  01007  2016     Bibb  Alabama       AL  President  Hillary Clinton
# 4  01009  2016   Blount  Alabama       AL  President  Hillary Clinton
#
#    votes_dem candidate_gop  votes_gop  votes_total  votes_other  \
# 0     5936.0  Donald Trump    18172.0        24973        865.0
# 1    18458.0  Donald Trump    72883.0        95215       3874.0
# 2     4871.0  Donald Trump     5454.0        10469        144.0
# 3     1874.0  Donald Trump     6738.0         8819        207.0
# 4     2156.0  Donald Trump    22859.0        25588        573.0
#
#    voter_share_major_party  voter_share_dem  voter_share_gop  \
# 0                 0.965363         0.237697         0.727666
# 1                 0.959313         0.193856         0.765457
# 2                 0.986245         0.465278         0.520967
# 3                 0.976528         0.212496         0.764032
# 4                 0.977607         0.084258         0.893348
#
#    voter_share_other  rawdiff_dem_vs_gop  rawdiff_gop_vs_dem  \
# 0           0.034637            -12236.0             12236.0
# 1           0.040687            -54425.0             54425.0
# 2           0.013755              -583.0               583.0
# 3           0.023472             -4864.0              4864.0
# 4           0.022393            -20703.0             20703.0
#
#    rawdiff_dem_vs_other  rawdiff_gop_vs_other  rawdiff_other_vs_dem  \
# 0                5071.0               17307.0               -5071.0
# 1               14584.0               69009.0              -14584.0
# 2                4727.0                5310.0               -4727.0
# 3                1667.0                6531.0               -1667.0
# 4                1583.0               22286.0               -1583.0
#
#    rawdiff_other_vs_gop  pctdiff_dem_vs_gop  pctdiff_gop_vs_dem  \
# 0              -17307.0           -0.489969            0.489969
# 1              -69009.0           -0.571601            0.571601
# 2               -5310.0           -0.055688            0.055688
# 3               -6531.0           -0.551536            0.551536
# 4              -22286.0           -0.809090            0.809090
#
#    pctdiff_dem_vs_other  pctdiff_gop_vs_other  pctdiff_other_vs_dem  \
# 0              0.203059              0.693028             -0.203059
# 1              0.153169              0.724770             -0.153169
# 2              0.451524              0.507212             -0.451524
# 3              0.189024              0.740560             -0.189024
# 4              0.061865              0.870955             -0.061865
#
#    pctdiff_other_vs_gop  OBJECTID  GEOID                  GEONAME  \
# 0             -0.693028       1.0  01001  Autauga County, Alabama
# 1             -0.724770       2.0  01003  Baldwin County, Alabama
# 2             -0.507212       3.0  01005  Barbour County, Alabama
# 3             -0.740560       4.0  01007     Bibb County, Alabama
# 4             -0.870955       5.0  01009   Blount County, Alabama
#
#    Total_cvap_est                                              SHAPE  \
# 0         40690.0  {'rings': [[[-9619465, 3856529.0001000017], [-...
# 1        151770.0  {'rings': [[[-9746859, 3539643.0001000017], [-...
# 2         20375.0  {'rings': [[[-9468394, 3771591.0001000017], [-...
# 3         17590.0  {'rings': [[[-9692114, 3928124.0001000017], [-...
# 4         42430.0  {'rings': [[[-9623907, 4063676.0001000017], [-...
#
#     Shape__Area  Shape__Length  voter_turnout  voter_turnout_majparty  \
# 0  2.208654e+09   2.498864e+05       0.613738                0.592480
# 1  5.671048e+09   1.655940e+06       0.627364                0.601838
# 2  3.257902e+09   3.208964e+05       0.513816                0.506748
# 3  2.311999e+09   2.279184e+05       0.501364                0.489596
# 4  2.456909e+09   2.926429e+05       0.603064                0.589559
#
#    voter_turnout_dem  voter_turnout_gop  voter_turnout_other
# 0           0.145884           0.446596             0.021258
# 1           0.121618           0.480220             0.025525
# 2           0.239067           0.267681             0.007067
# 3           0.106538           0.383059             0.011768
# 4           0.050813           0.538746             0.013505

# %%
# Check for null values
data_2016_df.loc[data_2016_df['voter_turnout'].isnull()].shape[0]
# Out:
# 43

# %%
# Remove records with no voter turnout value
data_2016_df = data_2016_df.loc[data_2016_df['voter_turnout'].notnull()]
data_2016_df.shape[0]
# Out:
# 3111

# %%
# Run a describe to get the distribution of voter turnout values
data_2016_df['voter_turnout'].describe()
# Out:
# count    3111.000000
# mean        0.594528
# std         0.093493
# min         0.158585
# 25%         0.530778
# 50%         0.595395
# 75%         0.656265
# max         1.121277
# Name: voter_turnout, dtype: float64

# %%
# Perform query for voter turnout above 100%
data_2016_df.loc[data_2016_df['voter_turnout'] > 1]
# Out:
#        FIPS  year    county       state state_po     office    candidate_dem  \
# 311   08111  2016  San Juan    Colorado       CO  President  Hillary Clinton
# 1816  35021  2016   Harding  New Mexico       NM  President  Hillary Clinton
# 2684  48301  2016    Loving       Texas       TX  President  Hillary Clinton
# 2689  48311  2016  McMullen       Texas       TX  President  Hillary Clinton
#
#       votes_dem candidate_gop  votes_gop  votes_total  votes_other  \
# 311       265.0  Donald Trump      215.0          506         26.0
# 1816      156.0  Donald Trump      311.0          527         60.0
# 2684        4.0  Donald Trump       58.0           65          3.0
# 2689       40.0  Donald Trump      454.0          499          5.0
#
#       voter_share_major_party  voter_share_dem  voter_share_gop  \
# 311                  0.948617         0.523715         0.424901
# 1816                 0.886148         0.296015         0.590133
# 2684                 0.953846         0.061538         0.892308
# 2689                 0.989980         0.080160         0.909820
#
#       voter_share_other  rawdiff_dem_vs_gop  rawdiff_gop_vs_dem  \
# 311            0.051383                50.0               -50.0
# 1816           0.113852              -155.0               155.0
# 2684           0.046154               -54.0                54.0
# 2689           0.010020              -414.0               414.0
#
#       rawdiff_dem_vs_other  rawdiff_gop_vs_other  rawdiff_other_vs_dem  \
# 311                  239.0                 189.0                -239.0
# 1816                  96.0                 251.0                 -96.0
# 2684                   1.0                  55.0                  -1.0
# 2689                  35.0                 449.0                 -35.0
#
#       rawdiff_other_vs_gop  pctdiff_dem_vs_gop  pctdiff_gop_vs_dem  \
# 311                 -189.0            0.098814           -0.098814
# 1816                -251.0           -0.294118            0.294118
# 2684                 -55.0           -0.830769            0.830769
# 2689                -449.0           -0.829659            0.829659
#
#       pctdiff_dem_vs_other  pctdiff_gop_vs_other  pctdiff_other_vs_dem  \
# 311               0.472332              0.373518             -0.472332
# 1816              0.182163              0.476281             -0.182163
# 2684              0.015385              0.846154             -0.015385
# 2689              0.070140              0.899800             -0.070140
#
#       pctdiff_other_vs_gop  OBJECTID  GEOID                     GEONAME  \
# 311              -0.373518     301.0  08111   San Juan County, Colorado
# 1816             -0.476281    1807.0  35021  Harding County, New Mexico
# 2684             -0.846154    2674.0  48301        Loving County, Texas
# 2689             -0.899800    2679.0  48311      McMullen County, Texas
#
#       Total_cvap_est                                              SHAPE  \
# 311            495.0  {'rings': [[[-11964863, 4528625.000100002], [-...
# 1816           470.0  {'rings': [[[-11578210, 4330676.000100002], [-...
# 2684            60.0  {'rings': [[[-11502370, 3717641.0001000017], [...
# 2689           460.0  {'rings': [[[-10946606, 3326438.0001000017], [...
#
#        Shape__Area  Shape__Length  voter_turnout  voter_turnout_majparty  \
# 311   1.611963e+09  209299.379233       1.022222                0.969697
# 1816  8.400382e+09  492631.196575       1.121277                0.993617
# 2684  2.435674e+09  254898.035389       1.083333                1.033333
# 2689  3.882883e+09  253408.774844       1.084783                1.073913
#
#       voter_turnout_dem  voter_turnout_gop  voter_turnout_other
# 311            0.535354           0.434343             0.052525
# 1816           0.331915           0.661702             0.127660
# 2684           0.066667           0.966667             0.050000
# 2689           0.086957           0.986957             0.010870

# %%
# correct data
# Correct each county
data_2016_df.loc[data_2016_df['FIPS'] == "08111", "Total_cvap_est"] = 574
data_2016_df.loc[data_2016_df['FIPS'] == "35021", "Total_cvap_est"] = 562
data_2016_df.loc[data_2016_df['FIPS'] == "48301", "Total_cvap_est"] = 86
data_2016_df.loc[data_2016_df['FIPS'] == "48311", "Total_cvap_est"] = 566

# %%
# Recalculate voter turnout fields
data_2016_df['voter_turnout'] = data_2016_df['votes_total'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_majparty'] = (data_2016_df['votes_dem']+data_2016_df['votes_gop']) / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_dem'] = data_2016_df['votes_dem'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_gop'] = data_2016_df['votes_gop'] / data_2016_df['Total_cvap_est']
data_2016_df['voter_turnout_other'] = data_2016_df['votes_other'] / data_2016_df['Total_cvap_est']

# %%
data_2016_df.loc[data_2016_df['voter_turnout'] > 1].shape[0]
# Out:
# 0

# %% [markdown]
# ## Convert dataframes to feature classes
# You will use the ArcGIS API for Python, imported at the beginning of this script, to export the spatially-enabled dataframe to a feature class.
